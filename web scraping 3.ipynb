# %% [markdown]
# # Ques1

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import re

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-2-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url='https://www.amazon.in/'
driver.get(url)

# %%
product=input('Enter the product name')
type_button=driver.find_element_by_id('twotabsearchtextbox')
type_button.clear()
type_button.send_keys(product)

search=driver.find_element_by_id('nav-search-submit-button')
search.click()
# Out:
# Enter the product namesmart phone
# <ipython-input-7-4f234c0fc71e>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   type_button=driver.find_element_by_id('twotabsearchtextbox')
# <ipython-input-7-4f234c0fc71e>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search=driver.find_element_by_id('nav-search-submit-button')

# %% [markdown]
# # Ques2

# %%
next_urls=[]
url_tags=driver.find_elements_by_xpath('//div[@class="a-section a-spacing-large a-spacing-top-large a-text-center s-pagination-container"]//a')
for i in url_tags[ :3]:
    next_urls.append(i.get_attribute('href'))
next_urls
# Out:
# <ipython-input-9-bc67ce2afe45>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath('//div[@class="a-section a-spacing-large a-spacing-top-large a-text-center s-pagination-container"]//a')
# ['https://www.amazon.in/s?k=smartphone&page=2&crid=115I1JFOCEB4B&qid=1640507221&sprefix=%2Caps%2C850&ref=sr_pg_2',
#  'https://www.amazon.in/s?k=smartphone&page=3&crid=115I1JFOCEB4B&qid=1640507221&sprefix=%2Caps%2C850&ref=sr_pg_3',
#  'https://www.amazon.in/s?k=smartphone&page=2&crid=115I1JFOCEB4B&qid=1640507221&sprefix=%2Caps%2C850&ref=sr_pg_1']

# %%
product_name=[]
for i in next_urls:
    driver.get(i)
    pro_tag=driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
    for i in pro_tag:
        product_name.append(i.text)
price=[]
for i in next_urls:
    driver.get(i)
    pri=driver.find_elements_by_xpath('//span[@class="a-price-whole"]')
    for i in pri:
        price.append(i.text)
expected_delivery=[]
for i in next_urls:
    driver.get(i)
    deli=driver.find_elements_by_xpath('//span[@class="a-text-bold"]')
    for i in deli:
        expected_delivery.append(i.text)  
product_url=[]
for i in next_urls:
    driver.get(i)
    p_u=driver.find_elements_by_xpath('a[@class="a-link-normal a-text-normal"]')
    for i in p_u:
        product_url.append(i.get__attribute('href'))
# Out:
# <ipython-input-10-4a9b396cc204>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   pro_tag=driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
# <ipython-input-10-4a9b396cc204>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   pri=driver.find_elements_by_xpath('//span[@class="a-price-whole"]')
# <ipython-input-10-4a9b396cc204>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   deli=driver.find_elements_by_xpath('//span[@class="a-text-bold"]')
# <ipython-input-10-4a9b396cc204>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   p_u=driver.find_elements_by_xpath('a[@class="a-link-normal a-text-normal"]')

# %%
amazon_phones=pd.DataFrame()
amazon_phones['product_name']=product_name[:30]
amazon_phones['price']=price[:30]
amazon_phones
# Out:
#                                          product_name   price
# 0   Samsung Galaxy M12 (Black,4GB RAM, 64GB Storag...  12,999
# 1   Samsung Galaxy M21 2021 Edition (Arctic Blue, ...   8,999
# 2   Samsung Galaxy M12 (Black,4GB RAM, 64GB Storag...  11,499
# 3   Samsung Galaxy M12 (Black,6GB RAM, 128GB Stora...  13,499
# 4   Panasonic Eluga I6 (Black, 2GB Ram, 16GB Stora...   5,489
# 5   realme narzo 50i (Carbon Black, 4GB RAM+64GB S...   8,999
# 6   Redmi 9 Activ (Metallic Purple, 6GB RAM, 128GB...  11,499
# 7   Vivo Y21 (Diamond Glow, 4GB RAM, 64GB Storage)...  13,990
# 8   realme narzo 50A (Oxygen Blue, 4GB RAM + 64GB ...  11,499
# 9   Tecno Spark 8T (Atlantic Blue,4GB RAM, 64GB St...   8,999
# 10  Tecno Spark 8T (Atlantic Blue,4GB RAM, 64GB St...  13,499
# 11  OnePlus 9 5G (Arctic Sky, 8GB RAM, 128GB Storage)  49,999
# 12  Nokia C01 Plus 4G, 5.45” HD+ Screen, Selfie Ca...   6,198
# 13  realme narzo 50A (Oxygen Blue, 4GB RAM + 128GB...  12,499
# 14            I KALL Z8 Smartphone (3GB, 16GB) (Blue)   4,999
# 15       Moto a10_Dark Blue_Dual Sim 1750 mAh Battery   1,399
# 16  Redmi 10 (Prime Phantom Black 6GB RAM 128GB RO...   6,498
# 17    Jio Phone Next 32 GB, 2 GB RAM, Blue Smartphone     979
# 18  Lava A1 Josh 21-Dual Sim |Call Blink Notficati...   4,690
# 19  SHIVANSH Micromax Canvas C1 A (Color Assorted)...  29,999
# 20  Samsung Galaxy M52 5G (Blazing Black, 6GB RAM,...  20,999
# 21  Samsung Galaxy M32 5G (Sky Blue, 6GB RAM, 128G...  29,999
# 22  Samsung Galaxy M12 (Black,6GB RAM, 128GB Stora...  22,999
# 23  Tecno Spark 8T (Turquoise Cyan,4GB RAM, 64GB S...  11,499
# 24  Samsung Galaxy M32 5G (Sky Blue, 8GB RAM, 128G...   8,999
# 25           Moto E40 (Carbon Gray, 64 GB) (4 GB RAM)  22,999
# 26  Realme GT 5G Master Edition (Daybreak Blue, 8G...  25,199
# 27  Nokia G20, 48MP Quad Camera, 5050 mAh Battery,...  12,490
# 28  Tecno Spark Go 2021 (Maldives Blue, 2GB RAM, 3...   7,299
# 29  I KALL Z5 Smartphone (3GB, 16GB, Android 10) (...   4,999

# %%
driver.close()

# %% [markdown]
# # Ques 3

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-22-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url='https://images.google.com/'
driver.get(url)

# %%
search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search_bar.send_keys('fruits')
# Out:
# <ipython-input-24-858376cd67ad>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
button.click()
# Out:
# <ipython-input-25-aa614f3e459a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
##scrolling full page
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
img_urls = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
len(img_urls)
# Out:
# <ipython-input-27-da3893ee1a0d>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
# 154

# %% [markdown]
# # Fruits

# %%
import requests
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\Mohit Jha\Desktop\Images\Fruits"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %% [markdown]
# # cars

# %%
search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search_bar.send_keys('Cars')
# Out:
# <ipython-input-44-34900024159a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
button.click()
# Out:
# <ipython-input-45-aa614f3e459a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
##scrolling full page
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
cars = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
cars_urls = []
for i in cars:
    source= i.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            cars_urls.append(source)
len(cars_urls)
# Out:
# <ipython-input-48-8c8573d2ca11>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cars = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
# 174

# %%
import requests
for i in range(len(cars_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(cars_urls[i])
    file = open(r"C:\Users\Mohit Jha\Desktop\Cars\Cars"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %% [markdown]
# # Machine Learing

# %%
search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search_bar.send_keys('Machine Learning')
# Out:
# <ipython-input-39-f57227336be0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")

# %%
button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
button.click()
# Out:
# <ipython-input-40-aa614f3e459a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")

# %%
##scrolling full page
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
machine = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
# Out:
# <ipython-input-41-a75e6397c574>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   machine = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

# %%
machine_urls = []
for i in machine:
    source= i.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            machine_urls.append(source)
len(machine_urls)
# Out:
# 114

# %%
import requests
for i in range(len(machine_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(machine_urls[i])
    file = open(r"C:\Users\Mohit Jha\Desktop\my machine\machine"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
driver.close()

# %% [markdown]
# # Ques 4

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-52-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
url='http://www.flipkart.com/'
driver.get(url)

# %%
type_product=driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
type_product.send_keys('samsung smartphones')
# Out:
# <ipython-input-54-4a2080495b61>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   type_product=driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")

# %%
button=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
button.click()
# Out:
# <ipython-input-55-46d18b8945f0>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")

# %%
url=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    url.append(i.get_attribute('href'))
# Out:
# <ipython-input-56-d793d4d7a39d>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):

# %%
len(url)
# Out:
# 24

# %%
brand=[]
name=[]
color=[]
ram=[]
rom=[]
p_camera=[]
s_camera=[]
Display_Size=[]
Display_Resolution=[]
Processor=[]
Processor_core=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]
for ur in url:
    driver.get(ur)
     ## Read more
    read_more=driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    read_more.click()
    time.sleep(2)
    
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_30jeq3 _16Jk6d']"):
            Price.append(i.text)
    except NoSuchElementException:
        Price.append('--')  
    
    try:
        for i in driver.find_elements_by_xpath("//h1[@class='yhB1nd']//span"):
            brand.append(i.text.split()[0])
    except NoSuchElementException:
        brand.append('--')
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[3]/td[2]/ul/li"):
            name.append(i.text)
    except NoSuchElementException:
        name.append('--')
        
    try: 
        for i in driver.find_elements_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li"):
            color.append(i.text)
    except NoSuchElementException:
        color.append('--')
        
   
    
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[2]/td[2]/ul/li"):
            ram.append(i.text)
    except NoSuchElementException:
        ram.append('--')
        
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[1]/td[2]/ul/li"):
            rom.append(i.text)
    except NoSuchElementException:
        rom.append('--')
        
    try:
        for i in driver.find_elements_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li'):
            p_camera.append(i.text)
    except NoSuchElementException:
        p_camera.append('--')
      
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[5]/table/tbody/tr[5]/td[2]/ul/li"):
            s_camera.append(i.text)
    except NoSuchElementException:
        s_camera.append('--')
        
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[2]/table/tbody/tr[1]/td[2]/ul/li"):
            Display_Size.append(i.text)
    except NoSuchElementException:
        Display_Size.append('--')  
        
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[2]/table/tbody/tr[2]/td[2]/ul/li"):
            Display_Resolution.append(i.text)
    except NoSuchElementException:
        Display_Resolution.append('--') 
        
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[3]/table/tbody/tr[2]/td[2]/ul/li"):
            Processor.append(i.text)
    except NoSuchElementException:
        Processor.append('--') 
        
    try: 
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[3]/table/tbody/tr[3]/td[2]/ul/li"):
            Processor_core.append(i.text)
    except NoSuchElementException:
        Processor_core.append('--')        
            
    try:
        for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[10]/table/tbody/tr[1]/td[2]/ul/li"):
            Battery_Capacity.append(i.text)
    except NoSuchElementException:
        Battery_Capacity.append('--')
        
    Product_URL.append(ur)
    time.sleep(3)
# Out:
# <ipython-input-59-cfb486b028e4>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   read_more=driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
# <ipython-input-59-cfb486b028e4>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_30jeq3 _16Jk6d']"):
# <ipython-input-59-cfb486b028e4>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//h1[@class='yhB1nd']//span"):
# <ipython-input-59-cfb486b028e4>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[3]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_3k-BhJ'][1]/table/tbody/tr[4]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[2]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:54: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[4]/table/tbody/tr[1]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:60: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li'):
# <ipython-input-59-cfb486b028e4>:66: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[5]/table/tbody/tr[5]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:72: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[2]/table/tbody/tr[1]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:78: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[2]/table/tbody/tr[2]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:84: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[3]/table/tbody/tr[2]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:90: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[3]/table/tbody/tr[3]/td[2]/ul/li"):
# <ipython-input-59-cfb486b028e4>:96: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='_1UhVsV']/div[10]/table/tbody/tr[1]/td[2]/ul/li"):

# %%
print(len(brand))
print(len(name))
print(len(color))
print(len(ram))
print(len(rom))
    
print(len(p_camera))

print(len(Display_Size))
print(len(Display_Resolution))
    
print(len(Processor))
print(len(Processor_core))

print(len(Price))
print(len(Product_URL))
# Out:
# 19
# 24
# 24
# 24
# 24

# %%
df=pd.DataFrame({'Brand':brand,'Name':name,'Color':color,'RAM':ram,'ROM':rom,'Primary Camera':p_camera,
                'Display Size':Display_Size,'Display Resolution':Display_Resolution,'Processor':Processor,'Processor_core':Processor_core,
                'Price':Price,'Product_URL':Product_URL})

# %%
df
# Out:
#       Brand             Name              Color   RAM     ROM  \
# 0   SAMSUNG       Galaxy F22         Denim Blue  6 GB  128 GB
# 1   SAMSUNG       Galaxy F12           Sky Blue  4 GB   64 GB
# 2   SAMSUNG       Galaxy F22        Denim Black  6 GB  128 GB
# 3   SAMSUNG       Galaxy F12          Sea Green  4 GB   64 GB
# 4   SAMSUNG       Galaxy F12    Celestial Black  4 GB   64 GB
# 5   SAMSUNG       Galaxy M12              Black  4 GB   64 GB
# 6   SAMSUNG       Galaxy M12               Blue  4 GB   64 GB
# 7   SAMSUNG       Galaxy F22         Denim Blue  4 GB   64 GB
# 8   SAMSUNG       Galaxy F22        Denim Black  4 GB   64 GB
# 9   SAMSUNG       Galaxy M12               Blue  6 GB  128 GB
# 10  SAMSUNG       Galaxy M12              Black  6 GB  128 GB
# 11  SAMSUNG       Galaxy F12           Sky Blue  4 GB  128 GB
# 12  SAMSUNG    Galaxy M32 5G           Sky Blue  8 GB  128 GB
# 13  SAMSUNG       Galaxy F12          Sea Green  4 GB  128 GB
# 14  SAMSUNG           M32 5G        Slate Black  6 GB  128 GB
# 15  SAMSUNG    Galaxy A22 5G               Mint  6 GB  128 GB
# 16  SAMSUNG   Galaxy A52s 5G       Awesome Mint  8 GB  128 GB
# 17  SAMSUNG       Galaxy M32         Light Blue  6 GB  128 GB
# 18  SAMSUNG       Galaxy M32              Black  6 GB  128 GB
# 19  SAMSUNG      Galaxy A70s  Prism Crush White  8 GB  128 GB
# 20  SAMSUNG       Galaxy F12    Celestial Black  4 GB  128 GB
# 21  SAMSUNG  Galaxy A03 Core               Blue  2 GB   32 GB
# 22  SAMSUNG  Galaxy A03 Core              Black  2 GB   32 GB
# 23  SAMSUNG       Galaxy A52      Awesome Black  6 GB  128 GB
#
#              Primary Camera           Display Size   Display Resolution  \
# 0    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 1    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 2    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 3    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 4    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 5            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 6            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 7    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 8    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 9            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 10           Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 11   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 12   48MP + 8MP + 5MP + 2MP    16.51 cm (6.5 inch)   720 X 1600$$pixels
# 13   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 14   48MP + 8MP + 5MP + 2MP    16.51 cm (6.5 inch)   720 X 1600$$Pixels
# 15         48MP + 5MP + 2MP    16.76 cm (6.6 inch)   2408 x 1080 Pixels
# 16           Primary Camera    16.51 cm (6.5 inch)  1000 x 2400$$Pixels
# 17   64MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)   2400 x 1080 Pixels
# 18   64MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)   2400 x 1080 Pixels
# 19         64MP + 5MP + 8MP    17.02 cm (6.7 inch)   1080 x 2400 Pixels
# 20   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 21          8MP Rear Camera    16.51 cm (6.5 inch)    1600 x 720 Pixels
# 22          8MP Rear Camera    16.51 cm (6.5 inch)    1600 x 720 Pixels
# 23  64MP + 12MP + 5MP + 5MP    16.51 cm (6.5 inch)   2400 x 1080 Pixels
#
#                            Processor Processor_core    Price  \
# 0                 MediaTek Helio G80      Octa Core  ₹14,999
# 1                         Exynos 850      Octa Core  ₹11,499
# 2                 MediaTek Helio G80      Octa Core  ₹14,999
# 3                         Exynos 850      Octa Core  ₹11,499
# 4                         Exynos 850      Octa Core  ₹11,499
# 5                          Octa Core          2 GHz  ₹11,172
# 6                          Octa Core          2 GHz  ₹11,240
# 7                 MediaTek Helio G80      Octa Core  ₹12,999
# 8                 MediaTek Helio G80      Octa Core  ₹12,999
# 9                          Octa Core          2 GHz  ₹13,779
# 10                         Octa Core          2 GHz  ₹14,177
# 11                        Exynos 850      Octa Core  ₹12,499
# 12                  Dimensity 720 5G      Octa Core  ₹21,584
# 13                        Exynos 850      Octa Core  ₹12,499
# 14                  Dimensity 720 5G      Octa Core  ₹19,000
# 15  MediaTek Dimensity 700 (MT6833V)      Octa Core  ₹18,390
# 16                         Octa Core        1.8 GHz  ₹32,900
# 17                MediaTek Helio G80      Octa Core  ₹17,899
# 18                MediaTek Helio G80      Octa Core  ₹17,785
# 19                   Qualcomm SM6150      Octa Core  ₹19,999
# 20                        Exynos 850      Octa Core  ₹12,499
# 21                         Octa Core        1.6 GHz   ₹7,999
# 22                         Octa Core        1.6 GHz   ₹7,999
# 23          Qualcomm Snapdragon 720G      Octa Core  ₹26,792
#
#                                           Product_URL
# 0   https://www.flipkart.com/samsung-galaxy-f22-de...
# 1   https://www.flipkart.com/samsung-galaxy-f12-sk...
# 2   https://www.flipkart.com/samsung-galaxy-f22-de...
# 3   https://www.flipkart.com/samsung-galaxy-f12-se...
# 4   https://www.flipkart.com/samsung-galaxy-f12-ce...
# 5   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 6   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 7   https://www.flipkart.com/samsung-galaxy-f22-de...
# 8   https://www.flipkart.com/samsung-galaxy-f22-de...
# 9   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 10  https://www.flipkart.com/samsung-galaxy-m12-bl...
# 11  https://www.flipkart.com/samsung-galaxy-f12-sk...
# 12  https://www.flipkart.com/samsung-galaxy-m32-5g...
# 13  https://www.flipkart.com/samsung-galaxy-f12-se...
# 14  https://www.flipkart.com/samsung-m32-5g-slate-...
# 15  https://www.flipkart.com/samsung-galaxy-a22-5g...
# 16  https://www.flipkart.com/samsung-galaxy-a52s-5...
# 17  https://www.flipkart.com/samsung-galaxy-m32-li...
# 18  https://www.flipkart.com/samsung-galaxy-m32-bl...
# 19  https://www.flipkart.com/samsung-galaxy-a70s-p...
# 20  https://www.flipkart.com/samsung-galaxy-f12-ce...
# 21  https://www.flipkart.com/samsung-galaxy-a03-co...
# 22  https://www.flipkart.com/samsung-galaxy-a03-co...
# 23  https://www.flipkart.com/samsung-galaxy-a52-aw...

# %%
# Out:
#       Brand             Name              Color   RAM     ROM  \
# 0   SAMSUNG       Galaxy F22         Denim Blue  6 GB  128 GB
# 1   SAMSUNG       Galaxy F12           Sky Blue  4 GB   64 GB
# 2   SAMSUNG       Galaxy F22        Denim Black  6 GB  128 GB
# 3   SAMSUNG       Galaxy F12          Sea Green  4 GB   64 GB
# 4   SAMSUNG       Galaxy F12    Celestial Black  4 GB   64 GB
# 5   SAMSUNG       Galaxy M12              Black  4 GB   64 GB
# 6   SAMSUNG       Galaxy M12               Blue  4 GB   64 GB
# 7   SAMSUNG       Galaxy F22         Denim Blue  4 GB   64 GB
# 8   SAMSUNG       Galaxy F22        Denim Black  4 GB   64 GB
# 9   SAMSUNG       Galaxy M12               Blue  6 GB  128 GB
# 10  SAMSUNG       Galaxy M12              Black  6 GB  128 GB
# 11  SAMSUNG       Galaxy F12           Sky Blue  4 GB  128 GB
# 12  SAMSUNG    Galaxy M32 5G           Sky Blue  8 GB  128 GB
# 13  SAMSUNG       Galaxy F12          Sea Green  4 GB  128 GB
# 14  SAMSUNG           M32 5G        Slate Black  6 GB  128 GB
# 15  SAMSUNG    Galaxy A22 5G               Mint  6 GB  128 GB
# 16  SAMSUNG   Galaxy A52s 5G       Awesome Mint  8 GB  128 GB
# 17  SAMSUNG       Galaxy M32         Light Blue  6 GB  128 GB
# 18  SAMSUNG       Galaxy M32              Black  6 GB  128 GB
# 19  SAMSUNG      Galaxy A70s  Prism Crush White  8 GB  128 GB
# 20  SAMSUNG       Galaxy F12    Celestial Black  4 GB  128 GB
# 21  SAMSUNG  Galaxy A03 Core               Blue  2 GB   32 GB
# 22  SAMSUNG  Galaxy A03 Core              Black  2 GB   32 GB
# 23  SAMSUNG       Galaxy A52      Awesome Black  6 GB  128 GB
#
#              Primary Camera           Display Size   Display Resolution  \
# 0    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 1    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 2    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 3    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 4    48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 5            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 6            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 7    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 8    48MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)    1600 x 720 Pixels
# 9            Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 10           Primary Camera    16.51 cm (6.5 inch)     720*1600$$pixels
# 11   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 12   48MP + 8MP + 5MP + 2MP    16.51 cm (6.5 inch)   720 X 1600$$pixels
# 13   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 14   48MP + 8MP + 5MP + 2MP    16.51 cm (6.5 inch)   720 X 1600$$Pixels
# 15         48MP + 5MP + 2MP    16.76 cm (6.6 inch)   2408 x 1080 Pixels
# 16           Primary Camera    16.51 cm (6.5 inch)  1000 x 2400$$Pixels
# 17   64MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)   2400 x 1080 Pixels
# 18   64MP + 8MP + 2MP + 2MP    16.26 cm (6.4 inch)   2400 x 1080 Pixels
# 19         64MP + 5MP + 8MP    17.02 cm (6.7 inch)   1080 x 2400 Pixels
# 20   48MP + 5MP + 2MP + 2MP  16.55 cm (6.515 inch)    1600 x 720 Pixels
# 21          8MP Rear Camera    16.51 cm (6.5 inch)    1600 x 720 Pixels
# 22          8MP Rear Camera    16.51 cm (6.5 inch)    1600 x 720 Pixels
# 23  64MP + 12MP + 5MP + 5MP    16.51 cm (6.5 inch)   2400 x 1080 Pixels
#
#                            Processor Processor_core    Price  \
# 0                 MediaTek Helio G80      Octa Core  ₹14,999
# 1                         Exynos 850      Octa Core  ₹11,499
# 2                 MediaTek Helio G80      Octa Core  ₹14,999
# 3                         Exynos 850      Octa Core  ₹11,499
# 4                         Exynos 850      Octa Core  ₹11,499
# 5                          Octa Core          2 GHz  ₹11,172
# 6                          Octa Core          2 GHz  ₹11,240
# 7                 MediaTek Helio G80      Octa Core  ₹12,999
# 8                 MediaTek Helio G80      Octa Core  ₹12,999
# 9                          Octa Core          2 GHz  ₹13,779
# 10                         Octa Core          2 GHz  ₹14,177
# 11                        Exynos 850      Octa Core  ₹12,499
# 12                  Dimensity 720 5G      Octa Core  ₹21,584
# 13                        Exynos 850      Octa Core  ₹12,499
# 14                  Dimensity 720 5G      Octa Core  ₹19,000
# 15  MediaTek Dimensity 700 (MT6833V)      Octa Core  ₹18,390
# 16                         Octa Core        1.8 GHz  ₹32,900
# 17                MediaTek Helio G80      Octa Core  ₹17,899
# 18                MediaTek Helio G80      Octa Core  ₹17,785
# 19                   Qualcomm SM6150      Octa Core  ₹19,999
# 20                        Exynos 850      Octa Core  ₹12,499
# 21                         Octa Core        1.6 GHz   ₹7,999
# 22                         Octa Core        1.6 GHz   ₹7,999
# 23          Qualcomm Snapdragon 720G      Octa Core  ₹26,792
#
#                                           Product_URL
# 0   https://www.flipkart.com/samsung-galaxy-f22-de...
# 1   https://www.flipkart.com/samsung-galaxy-f12-sk...
# 2   https://www.flipkart.com/samsung-galaxy-f22-de...
# 3   https://www.flipkart.com/samsung-galaxy-f12-se...
# 4   https://www.flipkart.com/samsung-galaxy-f12-ce...
# 5   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 6   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 7   https://www.flipkart.com/samsung-galaxy-f22-de...
# 8   https://www.flipkart.com/samsung-galaxy-f22-de...
# 9   https://www.flipkart.com/samsung-galaxy-m12-bl...
# 10  https://www.flipkart.com/samsung-galaxy-m12-bl...
# 11  https://www.flipkart.com/samsung-galaxy-f12-sk...
# 12  https://www.flipkart.com/samsung-galaxy-m32-5g...
# 13  https://www.flipkart.com/samsung-galaxy-f12-se...
# 14  https://www.flipkart.com/samsung-m32-5g-slate-...
# 15  https://www.flipkart.com/samsung-galaxy-a22-5g...
# 16  https://www.flipkart.com/samsung-galaxy-a52s-5...
# 17  https://www.flipkart.com/samsung-galaxy-m32-li...
# 18  https://www.flipkart.com/samsung-galaxy-m32-bl...
# 19  https://www.flipkart.com/samsung-galaxy-a70s-p...
# 20  https://www.flipkart.com/samsung-galaxy-f12-ce...
# 21  https://www.flipkart.com/samsung-galaxy-a03-co...
# 22  https://www.flipkart.com/samsung-galaxy-a03-co...
# 23  https://www.flipkart.com/samsung-galaxy-a52-aw...

# %%
driver.close()

# %% [markdown]
# # Ques 5

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-2-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.google.com/maps")
driver.maximize_window()
time.sleep(2)

# %%
#finding the search bar
srch_bar = driver.find_element(By.XPATH,'//input[@class="tactile-searchbox-input"]')    
srch_bar.clear()                                               
srch_bar.send_keys(input('Enter the city name: ')) 

#finding the search button and clicking
srch_button = driver.find_element(By.XPATH,'//button[@id="searchbox-searchbutton"]')       
srch_button.click()
time.sleep(3)

#getting the current url
Location=driver.current_url

try:
    coordinates=re.findall(r'@(.*)data',Location)
    lat_lon=coordinates[0].split(",")
    lat=lat_lon[0]
    lon=lat_lon[1]
except IndexError as e:
    coordinates=re.findall(r'@(.*)z',Location)
    lat_lon=coordinates[0].split(",")
    lat=lat_lon[0]
    lon=lat_lon[1]
print("\nlatitude={},longitude={}".format(lat,lon))
# Out:
# Enter the city name: gwalior
#
# latitude=26.214396,longitude=78.0508094

# %%
driver.close()

# %% [markdown]
# # Ques 6

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-9-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://trak.in/")
driver.maximize_window()
time.sleep(2)

# %%
fun_btn=driver.find_element(By.XPATH,"//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(fun_btn)

# %%
funding={}
funding["Date"]=[]
funding["Startup Name"]=[]
funding["Industry or Vertical"]=[]
funding["Sub Vertical"]=[]
funding["Location"]=[]
funding["Investor"]=[]
funding["Investment Type"]=[]
funding["Amount (in $)"]=[]

for i in range(54,57):
    driver.find_element(By.XPATH,'//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()

    # Scraping data of Date
    date_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for date in date_tags:
        funding['Date'].append(date.text)

    # Scraping data of Startup Name
    name_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for name in name_tags:
        funding['Startup Name'].append(name.text)
    
    # Scraping data of Industry OR Vertical
    ind_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind_tags:
        funding['Industry or Vertical'].append(n.text)
    
    # Scraping data of Sub-Vertical
    sv_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for sv in sv_tags:
        funding['Sub Vertical'].append(sv.text)

    # Scraping data of Location
    loc_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for loc in loc_tags:
        funding['Location'].append(loc.text)
    
    # Scraping data of Investor
    inv_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for inv in inv_tags:
        funding['Investor'].append(inv.text)
        
    # Scraping data of Investment Type
    invt_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for invt in invt_tags:
        funding['Investment Type'].append(invt.text)
    # Scraping data of Amount
    amt_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for amt in amt_tags:
        funding['Amount (in $)'].append(amt.text)

# %%
df=pd.DataFrame(funding)
df
# Out:
#           Date            Startup Name    Industry or Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#    Amount (in $)
# 0    1,80,00,000
# 1   6,172,258.50
# 2     30,000,000
# 3     15,000,000
# 4     16,000,000
# 5     15,000,000
# 6    100,000,000
# 7      4,000,000
# 8      2,500,000
# 9    250,000,000
# 10  2,747,045.20
# 11   1,50,00,000
# 12    75,000,000
# 13     4,773,958
# 14    55,000,000
# 15    15,000,000
# 16    18,000,000
# 17   250,000,000
# 18   140,000,000
# 19     8,000,000
# 20   460,000,000
# 21   300,000,000
# 22    11,000,000
# 23    27,500,000

# %%
driver.close()

# %% [markdown]
# # Ques 7

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-38-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.digit.in/")
driver.maximize_window()
time.sleep(2)

# %%
top10btn = driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[4]/a')
top10btn.click()
# Out:
# <ipython-input-40-979a8449f0b9>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   top10btn = driver.find_element_by_xpath('/html/body/div[1]/div/div[4]/ul/li[4]/a')

# %%
gaminglaptopbtn = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[3]/div[2]/ul/li[26]/a')
gaminglaptopbtn.click()
# Out:
# <ipython-input-41-7d96cf0a4b8e>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   gaminglaptopbtn = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[3]/div[2]/ul/li[26]/a')

# %%
# create empty list
name = []
os = []
disp = []
mem = []
price = []
Processor = []
GraphProc= []
dim = []
wt = []


# Scrape all name tag
name_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[1]")
for n in name_tag:
    name.append(n.text)
    
# Scrape all price tag
price_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[3]")
for p in price_tag:
    price.append(p.text)
    
# Scrape all OS tag
os_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
for o in os_tag:
    os.append(o.text)
    
# Scrape all display tag
disp_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
for d in disp_tag:
    disp.append(d.text)
    
# Scrape all Processor tag
Processor_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
for k in Processor_tag:
    Processor.append(k.text)
    
# Scrape all Graphic tag
GraphProc_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for g in GraphProc_tag:
    GraphProc.append(g.text)
    
# Scrape all memory tag
mem_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
for m in mem_tag:
    mem.append(g.text)
    
# Scrape all dimension tag
dim_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
for di in dim_tag:
    dim.append(di.text)
    
# Scrape all weight tag
wt_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
for w in wt_tag:
    wt.append(w.text)
    
# Scrape all description tag
desc_tag = driver.find_elements_by_xpath("//div[@class='Section-center']//p")
for des in desc_tag:
    desc.append(des.text)
# Out:
# <ipython-input-42-f0b833556836>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[1]")
# <ipython-input-42-f0b833556836>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price_tag  = driver.find_elements_by_xpath("//*[@id='summtable']/tbody/tr/td[3]")
# <ipython-input-42-f0b833556836>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[3]/td[3]")
# <ipython-input-42-f0b833556836>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   disp_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[4]/td[3]")
# <ipython-input-42-f0b833556836>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Processor_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[5]/td[3]")
# <ipython-input-42-f0b833556836>:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   GraphProc_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
# <ipython-input-42-f0b833556836>:44: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   mem_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[6]/td[3]")
# <ipython-input-42-f0b833556836>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dim_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[9]/td[3]")
# <ipython-input-42-f0b833556836>:54: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   wt_tag = driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr[7]/td[3]")
# <ipython-input-42-f0b833556836>:59: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc_tag = driver.find_elements_by_xpath("//div[@class='Section-center']//p")

# %%
Laptops = {'Laptop Name':name,'Operating System':os,'Display': disp,'Processor':Processor,'Graphics Processor':GraphProc ,'Memory':mem,'Dimensions':dim,'Weight(kg)':wt,'Price(₹)':price}

Laptops  = pd.DataFrame(Laptops)
Laptops
# Out:
#                                      Laptop Name Operating System  \
# 0                    Acer NITRO 5 Ryzen 9 (2021)       Windows 10
# 1  MSI Stealth 15M 11th Gen Core i7-11375H (2021       Windows 10
# 2   ASUS ROG Strix Scar 15 Ryzen 9-5900HX (2021)       Windows 10
# 3                          Alienware Area 51M R2  Windows 10 Home
# 4                               Alienware m15 R3  Windows 10 Home
# 5                         ASUS ROG Strix Scar 15  Windows 10 Home
# 6                          Asus ROG Zephyrus G14  Windows 10 Home
# 7                               Lenovo Legion 5i   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           Acer Aspire 7 gaming  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 x 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 x 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 x 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 x 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 x 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 x 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 x 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 x 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#         Graphics Processor              Memory                     Dimensions  \
# 0       363.4 x 255 x 23.9  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3070
# 1      358.3 x 248 x 16.15  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3060
# 2         354 x 259 x 22.6  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 3080
# 3   27.65 x 402.6 x 319.14  2.29 x 36.3 x 25.4        Intel® UHD Graphics 630
# 4                       NA  2.29 x 36.3 x 25.4                             NA
# 5       35.4 x 25.9 x 2.26  2.29 x 36.3 x 25.4      NVIDIA® GeForce RTX™ 3070
# 6        32.5 x 22.1 x 1.8  2.29 x 36.3 x 25.4        NVIDIA GeForce RTX 2060
# 7  363.06 x 259.61 x 23.57  2.29 x 36.3 x 25.4  NVIDIA® GeForce® GTX 1650 4GB
# 8  268.30 x 360.00 x 20.90  2.29 x 36.3 x 25.4  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.29 x 36.3 x 25.4  2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650
#
#   Weight(kg)   Price(₹)
# 0        2.4  ₹ 129,990
# 1        1.7  ₹ 134,990
# 2       2.30  ₹ 268,990
# 3        4.1  ₹ 342,989
# 4         NA  ₹ 319,990
# 5       2.30  ₹ 215,990
# 6       1.65  ₹ 164,990
# 7        2.3   ₹ 76,988
# 8        2.4  ₹ 185,000
# 9       2.15   ₹ 58,480

# %%
driver.close()

# %% [markdown]
# # Ques 8

# %%
driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-45-a1667afb9460>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Mohit Jha\Downloads\Compressed\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.forbes.com/?sh=63b020902254")
driver.maximize_window()
time.sleep(2)

# %%
Explbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[1]/button[1]')
Explbtn.click()
# Out:
# <ipython-input-48-82ac3676e089>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   Explbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[1]/button[1]')

# %%
bilbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]')
bilbtn.click()
# Out:
# <ipython-input-50-b04bbf823a94>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bilbtn = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]')

# %%
allbtn =  driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
allbtn.click()
# Out:
# <ipython-input-51-a189dea912d7>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   allbtn =  driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')

# %%
rank = []
name = []
netwrth = []
age = []
cit = []
src = []
ind = []

#Get Source
rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")

#scrape data
for r in rank_tag:
    rank.append(r.text)
for n in name_tag:
    name.append(n.text)
for nt in netwrth_tag:
    netwrth.append(nt.text)
for a in age_tag:
    age.append(a.text)
for c in cit_tag:
    cit.append(c.text)
for s in src_tag:
    src.append(s.text)
for i in ind_tag:
    ind.append(i.text)
# Out:
# <ipython-input-52-41e655c3f062>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-52-41e655c3f062>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
# <ipython-input-52-41e655c3f062>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
# <ipython-input-52-41e655c3f062>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
# <ipython-input-52-41e655c3f062>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-52-41e655c3f062>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
# <ipython-input-52-41e655c3f062>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")

# %%
i=0

while(i<=12):
    
    nextbtn = driver.find_element_by_xpath("//div[@class='next-page']")
    nextbtn.click()
    time.sleep(3)
    
    rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
    name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
    netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
    age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
    cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
    ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")
    for r in rank_tag:
            rank.append(r.text)
    for n in name_tag:
            name.append(n.text)
    for nt in netwrth_tag:
            netwrth.append(nt.text)
    for a in age_tag:
            age.append(a.text)
    for c in cit_tag:
            cit.append(c.text)  
    for s in src_tag:
            src.append(s.text)
    for k in ind_tag:
            ind.append(k.text)
    
    i=i+1
# Out:
# <ipython-input-53-dc0838a97a80>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nextbtn = driver.find_element_by_xpath("//div[@class='next-page']")
# <ipython-input-53-dc0838a97a80>:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank_tag = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-53-dc0838a97a80>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name_tag = driver.find_elements_by_xpath("//div[@class='personName']//div")
# <ipython-input-53-dc0838a97a80>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   netwrth_tag = driver.find_elements_by_xpath("//div[@class='netWorth']//div")
# <ipython-input-53-dc0838a97a80>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age_tag = driver.find_elements_by_xpath("//div[@class='age']//div")
# <ipython-input-53-dc0838a97a80>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit_tag = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-53-dc0838a97a80>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src_tag = driver.find_elements_by_xpath("//div[@class='source-column']//div")
# <ipython-input-53-dc0838a97a80>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind_tag = driver.find_elements_by_xpath("//div[@class='category']//div")

# %%
# Length of all the coloumns
len(rank),len(name),len(netwrth),len(age),len(cit),len(src),len(ind)
# Out:
# (2755, 2755, 5510, 2755, 2755, 5510, 2755)

# %%
#removing empty string values from netwrth
#netwrth
while('' in netwrth):  
    netwrth.remove("")

# %%
# replacing unwanted symbol with empty string
#src
for i in range(0,len(src)):
    if src[i] == '★': 
        src[i] = ''

# %%
rank = rank[0:2555]
src = src[0:2555]

# %%
billionaires = {'Rank':rank[:2555],'Name':name[:2555],'Net Worth':netwrth[:2555],'Age': age[:2555],'Citizenship/Country':cit[:2555],'Source':src[:2555],'Industry':ind[:2555]}

billionaires_df  = pd.DataFrame(billionaires)
billionaires_df
# Out:
#        Rank                      Name Net Worth Age Citizenship/Country  \
# 0        1.                Jeff Bezos    $177 B  57       United States
# 1        2.                 Elon Musk    $151 B  49       United States
# 2        3.  Bernard Arnault & family    $150 B  72              France
# 3        4.                Bill Gates    $124 B  65       United States
# 4        5.           Mark Zuckerberg     $97 B  36       United States
# ...     ...                       ...       ...  ..                 ...
# 2550  2524.  Antonio Gallardo Ballart    $1.1 B  85               Spain
# 2551  2524.    Jorge Gallardo Ballart    $1.1 B  79               Spain
# 2552  2524.             Gao Xingjiang    $1.1 B  57               China
# 2553  2524.              Rahul Gautam    $1.1 B  68               India
# 2554  2524.          Simona Giorgetta    $1.1 B  43               Italy
#
#                  Source                    Industry
# 0                Amazon                  Technology
# 1                                        Automotive
# 2         Tesla, SpaceX            Fashion & Retail
# 3                                        Technology
# 4                  LVMH                  Technology
# ...                 ...                         ...
# 2550     luxury fashion                  Healthcare
# 2551                                     Healthcare
# 2552            banking               Manufacturing
# 2553                               Fashion & Retail
# 2554  software services  Construction & Engineering
#
# [2555 rows x 7 columns]
