# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.dineout.co.in/delhi/farzi-cafe-connaught-place-central-delhi-20854')

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_title = soup.find('div',class_='restnt-details_info')

# %%
print(first_title)
# Out:
# <div class="restnt-details_info"><h1>Farzi Cafe</h1><div class="restnt-cost">₹ 2,000 for 2 | <a class="text-ltgrey" href="/delhi-restaurants/central-delhi/connaught-place/modern-indian-cuisine">Modern Indian</a>, <a class="text-ltgrey" href="/delhi-restaurants/central-delhi/connaught-place/continental-cuisine">Continental</a>, <a class="text-ltgrey" href="/delhi-restaurants/central-delhi/connaught-place/finger-food-cuisine">Finger Food</a></div><div class="restnt-name"><a class="text-ltgrey" href="/delhi-restaurants/central-delhi/connaught-place">Connaught Place | </a><a class="text-ltgrey" href="/delhi-restaurants">Delhi | </a><a class="text-blue font-bold" data-target="#direction" data-toggle="modal" data-w-onclick="restroNavClicked|w1" href="javascript:void(0)" item-clicked="direction"><img src="https://st1.dineout-cdn.co.in/images/uploads/mailer/2019/Jul/11/path.png"/> Get Direction</a></div><div class="timing">Time: <a aria-expanded="true" class="dropdown-toggle" data-action="rd
# ...

# %%
first_title.text
# Out:
# 'Farzi Cafe₹ 2,000 for 2 | Modern Indian, Continental, Finger FoodConnaught Place | Delhi |  Get DirectionTime:  (Opens at 12:00 PM)Sunday12:00 PM to 01:00 AMMonday12:00 PM to 01:00 AMTuesday12:00 PM to 01:00 AMWednesday12:00 PM to 01:00 AMThursday12:00 PM to 01:00 AMFriday12:00 PM to 01:00 AMSaturday12:00 PM to 01:00 AM'

# %%
#scraping name
name = first_title.text.split('|')[0:1]
''.join(name).replace('₹ 2,000 for 2','')

# %%
#scraping cuisin
cuision =first_title.text.split('|')[1:3]
cuision
''.join(cuision).replace('Connaught Place  Delhi' ,'')
# Out:
# ' Modern Indian, Continental, Finger Food '

# %%
#scraping location
location= first_title.text.split('|')[1:3]
''.join(cuision).replace('Modern Indian, Continental, Finger Food' ,'')
# Out:
# ' Connaught Place  Delhi '

# %%
#scraping rating
rating = soup.find('div',class_="rdp-restnt-rating")
rating.text
# Out:
# '4.2144 reviews'

# %%
#scraping image
image = soup.find('img',class_="rdp-banner_img")
print(image)
# Out:
# <img alt="Farzi Cafe Photos" class="rdp-banner_img" data-img-pixel="1200" data-position="0" height="445" src="https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/k/m/p4199-16098546105ff46e92bab5b.jpg?tr=tr:n-large" title="Farzi Cafe Photos" width="780"/>
